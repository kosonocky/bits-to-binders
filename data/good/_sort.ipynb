# %% [markdown]
# anything saved here will be saved to /good and have its index manually adjusted as we never ran original index 11985 and all indices after that were shifted

# %%
import pandas as pd

df = pd.read_csv("axis_angles_aterm_vs_bc.csv")
df = df.sort_values(by=["file"])

# df.to_csv("axis_angles_aterm_vs_bc.csv", index=False)

# %%
df = pd.read_csv("../needs_recomputing/phillip/outputs/cpu_boltz_rosetta_stats.csv")
df = df.sort_values(by=["name"])
df = df.drop(columns=["boltz", "scores", "pdb"]) # drop paths

# df.to_csv("cpu_boltz_rosetta_stats.csv", index=False)

# %%
df = pd.read_csv("../needs_recomputing/phillip/outputs/ipsae_stats.csv")
df = df.sort_values(by=["model"])

# df.to_csv("ipsae_stats.csv", index=False)

# %%
df = pd.read_csv("../needs_recomputing/phillip/outputs/thread_boltz_rosetta_stats.csv")
df = df.sort_values(by=["name"])
df = df.drop(columns=["boltz", "name.1", "scores", "pdb", "description"]) # drop paths

# df.to_csv("thread_boltz_rosetta_stats.csv", index=False)
